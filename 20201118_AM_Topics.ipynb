# %% [markdown]
# # Topic Model

# %% [markdown]
# This code has been adapted from the article Topic Modeling with Gensim (Python) by Selva Prabhakaran at https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %%
# Get Libraries
import nltk # Stopwords and other NLP
from nltk.corpus import stopwords
import re #Regex
import numpy as np #Math
import pandas as pd #Dataframe
from pprint import pprint
import spacy #Lemmatization

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Model & Data Prep

# %%
# Get stopwords
stop_words = stopwords.words('english')

# %%
# Import sentiment dataframe
df = pd.read_csv("20201117_AM_Sentiment.csv") 
df.head()
# Out:
#    Unnamed: 0                                           Sentence  \
# 0           0   baltimore 20 september 1836 dear heinrich: fr...
# 1           1                  it was a long and arduous voyage!
# 2           2  however we were and are all well and thank the...
# 3           3  i had written down the events of the voyage fo...
# 4           4               as you know, we set sail on 12 july.
#
#             fileid  Sequence  Sentiment
# 0  S10003-D023.txt         1     0.7263
# 1  S10003-D023.txt         2     0.0000
# 2  S10003-D023.txt         3     0.8777
# 3  S10003-D023.txt         4     0.2263
# 4  S10003-D023.txt         5     0.0000

# %%
# Place column values in a list
data = df.Sentence.values.tolist()
data[:5]
# Out:
# [' baltimore 20 september 1836 dear heinrich: friday evening, 16 september, anchor was dropped and we had safely arrived in the harbor!',
#  'it was a long and arduous voyage!',
#  'however we were and are all well and thank the father in heaven that he has protected us so far!',
#  'i had written down the events of the voyage for you, but to my great annoyance i am now missing the whole notebook; perhaps i will find it later.',
#  'as you know, we set sail on 12 july.']

# %%
# Function to tokenize 
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:5])
# Out:
# [['baltimore', 'september', 'dear', 'heinrich', 'friday', 'evening', 'september', 'anchor', 'was', 'dropped', 'and', 'we', 'had', 'safely', 'arrived', 'in', 'the', 'harbor'], ['it', 'was', 'long', 'and', 'arduous', 'voyage'], ['however', 'we', 'were', 'and', 'are', 'all', 'well', 'and', 'thank', 'the', 'father', 'in', 'heaven', 'that', 'he', 'has', 'protected', 'us', 'so', 'far'], ['had', 'written', 'down', 'the', 'events', 'of', 'the', 'voyage', 'for', 'you', 'but', 'to', 'my', 'great', 'annoyance', 'am', 'now', 'missing', 'the', 'whole', 'notebook', 'perhaps', 'will', 'find', 'it', 'later'], ['as', 'you', 'know', 'we', 'set', 'sail', 'on', 'july']]

# %%
# Bigram / trigram models
bigram = gensim.models.Phrases(data_words, min_count=20, threshold=100)
bigram_mod = gensim.models.phrases.Phraser(bigram)

# %%
# Functions for stopwords, bigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove stop words
data_words_nostops = remove_stopwords(data_words)

# Form bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy lemmatizer
nlp = spacy.load('en_core_web_md', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams)

# %%
# Create dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Initialize Mallet module
# Obtained from http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
mallet_path = 'mallet-2.0.8/bin/mallet'

# %% [markdown]
# ## Topics

# %%
# Run 9-topic model
ldamallet_09 = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=9, id2word=id2word)

# Show Topics
pprint(ldamallet_09.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet_09 = CoherenceModel(model=ldamallet_09, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet_09 = coherence_model_ldamallet_09.get_coherence()
print('Coherence Score: ', coherence_ldamallet_09)
# Out:
# [(0,
#   [('day', 0.07479980811100041),
#    ('leave', 0.036680320307022396),
#    ('week', 0.027381084172847705),
#    ('home', 0.024428945717554152),
#    ('back', 0.022546957452304513),
#    ('return', 0.021218495147422415),
#    ('night', 0.01693789438724676),
#    ('morning', 0.015757039005129342),
#    ('room', 0.015277316506144138),
#    ('hour', 0.014686888815085428)]),
#  (1,
#   [('place', 0.04003002251688766),
#    ('house', 0.026376925551306336),
#    ('mile', 0.024697094249258374),
#    ('large', 0.020265198899174382),
#    ('water', 0.015726080274491582),
#    ('town', 0.01472532971156939),
#    ('high', 0.013903284606311878),
#    ('city', 0.013545873690982523),
#    ('church', 0.013474391507916652),
#    ('stand', 0.012545123128060331)]),
#  (2,
#   [('write', 0.06192957174001404),
#    ('letter', 0.06122750618926209),
#    ('send', 0.04870117873110889),
#    ('long', 0.03857665447289658),
#    ('time', 0.03798544137752651),
#    ('hear', 0.03473376935299117),
#    ('receive', 0.031888556331522745),
#    ('answer', 0.01814285186416879),
#    ('girl', 0.017071278128810555),
#    ('read', 0.014891179839633447)]),
#  (3,
#   [('time', 0.04161553051433672),
#    ('people', 0.0397188441370077),
#    ('present', 0.01736769682769906),
#    ('bad', 0.014913161515861504),
#    ('meet', 0.014504072297221912),
#    ('world', 0.012161106772286065),
#    ('lose', 0.011937967198482651),
#    ('life', 0.01082226932946558),
#    ('change', 0.010599129755662167),
#    ('speak', 0.01048755996876046)]),
#  (4,
#   [('child', 0.0424995364361209),
#    ('dear', 0.039718153161505655),
#    ('live', 0.03571296124605971),
#    ('sister', 0.029742258483218986),
#    ('feel', 0.02951974782124977),
#    ('family', 0.02862970517337289),
#    ('love', 0.021435193769701464),
#    ('wife', 0.02128685332838865),
#    ('young', 0.021138512887075838),
#    ('brother', 0.020100129797886147)]),
#  (5,
#   [('bring', 0.02536997885835095),
#    ('small', 0.018597484502096247),
#    ('hand', 0.01745081879098434),
#    ('put', 0.014799154334038054),
#    ('fine', 0.01461998781667682),
#    ('foot', 0.012434156304869746),
#    ('carry', 0.01139499050417458),
#    ('open', 0.010929157559035367),
#    ('ship', 0.009459992116673236),
#    ('eye', 0.009352492206256495)]),
#  (6,
#   [('good', 0.08784485315929991),
#    ('make', 0.07913082171462474),
#    ('give', 0.051283002076535154),
#    ('find', 0.043495995253633936),
#    ('thing', 0.036228122218926136),
#    ('hope', 0.02573420350044497),
#    ('care', 0.015166122812221893),
#    ('turn', 0.012051320083061406),
#    ('health', 0.010716404627706911),
#    ('regard', 0.01034559477899733)]),
#  (7,
#   [('work', 0.056153590056597494),
#    ('man', 0.05341619502090038),
#    ('great', 0.03455036436947435),
#    ('call', 0.02267598860651796),
#    ('school', 0.01831095327932527),
#    ('order', 0.014204860725779603),
#    ('person', 0.014130877076166167),
#    ('hard', 0.013871934302519144),
#    ('mind', 0.013058114156771354),
#    ('hold', 0.011356490215662339)]),
#  (8,
#   [('year', 0.06252878449711269),
#    ('country', 0.03330144896730081),
#    ('land', 0.0289793460162256),
#    ('money', 0.027207992347752154),
#    ('dollar', 0.02600347185319021),
#    ('pay', 0.02522407623906189),
#    ('state', 0.01583590179615262),
#    ('farm', 0.014241683494526517),
#    ('sell', 0.013674850320615014),
#    ('month', 0.013356006660289793)])]
# Coherence Score:  0.40243838591242925

# %%
mallet2ldaModel_09 = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(ldamallet_09)

# %% [markdown]
# ## Evaluation

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(mallet2ldaModel_09, corpus, id2word)
vis
# Out:
# /Users/alaynemoody/.local/lib/python3.6/site-packages/pyLDAvis/_prepare.py:223: RuntimeWarning: divide by zero encountered in log
#   kernel = (topic_given_term * np.log((topic_given_term.T / topic_proportion).T))
# /Users/alaynemoody/.local/lib/python3.6/site-packages/pyLDAvis/_prepare.py:240: RuntimeWarning: divide by zero encountered in log
#   log_lift = np.log(topic_term_dists / term_proportion)
# /Users/alaynemoody/.local/lib/python3.6/site-packages/pyLDAvis/_prepare.py:241: RuntimeWarning: divide by zero encountered in log
#   log_ttd = np.log(topic_term_dists)
# /Users/alaynemoody/.local/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.146016  0.230898       1        1  11.358335
# 8     -0.202265 -0.163535       2        1  11.345776
# 1     -0.229070  0.079067       3        1  11.208428
# 7     -0.147425 -0.179577       4        1  11.123304
# 3      0.215942 -0.063209       5        1  11.059487
# 6      0.110615 -0.005056       6        1  11.024370
# 0      0.071927  0.228946       7        1  10.989712
# 4      0.129842 -0.226256       8        1  10.959580
# 2      0.196449  0.098722       9        1  10.931009, topic_info=     Category         Freq      Term        Total  loglift  logprob
# 78    Default  3069.000000      good  3069.000000  30.0000  30.0000
# 177   Default  2770.000000      make  2770.000000  29.0000  29.0000
# 36    Default  2605.000000       day  2605.000000  28.0000  28.0000
# 353   Default  2248.000000      year  2248.000000  27.0000  27.0000
# 23    Default  2148.000000     write  2148.000000  26.0000  26.0000
# 215   Default  2121.000000    letter  2121.000000  25.0000  25.0000
# 271   Default  1991.000000      work  1991.000000  24.0000  24.0000
# 45    Default  2791.000000      time  2791.000000  23.0000  23.0000
# 694   Default  1883.000000       man  1883.000000  22.0000  22.0000
# 435   Default  1687.000000      send  1687.000000  21.0000  21.0000
# 214   Default  2046.000000      give  2046.000000  20.0000  20.0000
# 28    Default  1476.000000     child  1476.000000  19.0000  19.0000
# 16    Default  1567.000000      find  1567.000000  18.0000  18.0000
# 324   Default  1422.000000     place  1422.000000  17.0000  17.0000
# 172   Default  1392.000000    people  1392.000000  16.0000  16.0000
# 725   Default  1379.000000      dear  1379.000000  15.0000  15.0000
# 7     Default  1506.000000      long  1506.000000  14.0000  14.0000
# 68    Default  1265.000000     thing  1265.000000  13.0000  13.0000
# 357   Default  1243.000000      live  1243.000000  12.0000  12.0000
# 31    Default  1434.000000     leave  1434.000000  11.0000  11.0000
# 422   Default  1203.000000      hear  1203.000000  10.0000  10.0000
# 202   Default  1197.000000   country  1197.000000   9.0000   9.0000
# 17    Default  1402.000000     great  1402.000000   8.0000   8.0000
# 98    Default  1104.000000   receive  1104.000000   7.0000   7.0000
# 222   Default  1033.000000    sister  1033.000000   6.0000   6.0000
# 70    Default  1042.000000      land  1042.000000   5.0000   5.0000
# 37    Default  1025.000000      feel  1025.000000   4.0000   4.0000
# 795   Default   994.000000    family   994.000000   3.0000   3.0000
# 1152  Default   978.000000     money   978.000000   2.0000   2.0000
# 263   Default   938.000000     house   938.000000   1.0000   1.0000
# ...       ...          ...       ...          ...      ...      ...
# 1420   Topic9   436.553706  daughter   436.553706   2.2136  -4.3740
# 427    Topic9   490.322784       ago   491.612816   2.2109  -4.2579
# 749    Topic9   340.537495       die   340.537495   2.2136  -4.6224
# 1522   Topic9   331.575982      book   331.575982   2.2136  -4.6491
# 564    Topic9   312.372740     paper   312.372740   2.2136  -4.7088
# 426    Topic9   299.570578      talk   299.570578   2.2136  -4.7506
# 1023   Topic9   295.729930     death   295.729930   2.2136  -4.7635
# 421    Topic9   281.647552  remember   281.647552   2.2136  -4.8123
# 771    Topic9   216.356529      true   216.356529   2.2136  -5.0760
# 1000   Topic9   209.955448  question   209.955448   2.2136  -5.1061
# 329    Topic9   197.153287      news   197.153287   2.2136  -5.1690
# 183    Topic9   515.927107      read   521.128074   2.2035  -4.2070
# 1583   Topic9   180.510477       add   180.510477   2.2136  -5.2572
# 639    Topic9   166.428099    finish   166.428099   2.2136  -5.3384
# 139    Topic9   156.186370      note   156.186370   2.2136  -5.4019
# 590    Topic9   153.625938  recently   153.625938   2.2136  -5.4184
# 1988   Topic9   252.202581      mail   253.472311   2.2085  -4.9227
# 341    Topic9   312.372740     today   314.980030   2.2053  -4.7088
# 569    Topic9   126.741399      date   126.741399   2.2136  -5.6108
# 19     Topic9   124.180966      miss   124.180966   2.2136  -5.6312
# 438    Topic9   120.340318  complain   120.340318   2.2136  -5.6626
# 720    Topic9   266.284958   mention   271.501690   2.1942  -4.8684
# 408    Topic9   216.356529   concern   220.267463   2.1957  -5.0760
# 7      Topic9  1336.545657      long  1506.829882   2.0936  -3.2551
# 274    Topic9   473.679974     visit   515.396611   2.1292  -4.2924
# 753    Topic9   327.735334       son   351.178716   2.1445  -4.6607
# 45     Topic9  1316.062199      time  2791.684922   1.4616  -3.2706
# 196    Topic9   227.878474   trouble   279.314364   2.0100  -5.0241
# 1      Topic9   331.575982    arrive   659.348235   1.5262  -4.6491
# 27     Topic9   345.658360     begin   739.521621   1.4530  -4.6075
#
# [643 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 14407      5  0.767080  abrogation
# 1329       2  0.997075      accord
# 1191       6  1.000908     account
# 450        2  0.999945        acre
# 1583       9  1.002712         add
# 585        5  0.997828     address
# 6837       3  0.787569   adherence
# 5809       4  1.022351    adoption
# 7531       9  0.986675       adore
# 1944       6  0.999812      advice
# 1250       3  0.021750      advise
# 1250       6  0.978733      advise
# 805        8  1.001108      afraid
# 9110       9  1.171677      afresh
# 1205       4  0.014737         age
# 1205       8  0.987367         age
# 427        1  0.002034         ago
# 427        9  0.996719         ago
# 11000      2  1.009197        agoe
# 6011       7  1.037306     ailment
# 269        1  0.998691         air
# 6325       6  1.157677    alienate
# 7856       5  0.767080       alley
# 6029       7  0.777979  ameliorate
# 339        3  0.998760    american
# 6917       3  0.787569     anatomy
# 503        8  0.001588      answer
# 503        9  0.998612      answer
# 6460       7  0.777979  applicable
# 6219       8  1.035014     archive
# ...      ...       ...         ...
# 616        8  0.999402        wife
# 239        6  0.019206      winter
# 239        7  0.979522      winter
# 7128       3  1.181353    withheld
# 6163       6  1.029046       witty
# 6411       7  1.006797        wolf
# 525        8  0.999076       woman
# 815        1  1.000954        wood
# 1976       1  0.986586      woolen
# 991        4  0.012240        word
# 991        5  0.712391        word
# 991        6  0.203191        word
# 991        8  0.073442        word
# 271        3  0.000502        work
# 271        4  0.994283        work
# 271        6  0.005022        work
# 633        5  0.999315       world
# 661        5  1.000045       worry
# 6707       3  0.787569     wrangle
# 23         8  0.001397       write
# 23         9  0.998967       write
# 1730       5  0.767080        yank
# 1977       1  0.986586        yarn
# 353        2  1.000176        year
# 197        7  1.000259   yesterday
# 1315       2  1.003982       yield
# 280        8  0.999606       young
# 5914       8  1.035014     younger
# 7778       5  0.767080       zigge
# 7803       5  0.767080      zinnia
#
# [743 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 9, 2, 8, 4, 7, 1, 5, 3])

# %% [markdown]
# ## Dominant topic in each sentence

# %%
def format_topics_sentences(model, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(model[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = model.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
# Run the function
df_topic_sents_keywords = format_topics_sentences(model=mallet2ldaModel_09, corpus=corpus, texts=data)

# %%
# Format output
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# View
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             1.0              0.1525
# 1            1             6.0              0.1420
# 2            2             7.0              0.1255
# 3            3             6.0              0.1575
# 4            4             0.0              0.1261
# 5            5             7.0              0.1408
# 6            6             0.0              0.1566
# 7            7             6.0              0.1285
# 8            8             0.0              0.2015
# 9            9             6.0              0.1424
#
#                                             Keywords  \
# 0  place, house, mile, large, water, town, high, ...
# 1  good, make, give, find, thing, hope, care, tur...
# 2  work, man, great, call, school, order, person,...
# 3  good, make, give, find, thing, hope, care, tur...
# 4  day, leave, week, home, back, return, night, m...
# 5  work, man, great, call, school, order, person,...
# 6  day, leave, week, home, back, return, night, m...
# 7  good, make, give, find, thing, hope, care, tur...
# 8  day, leave, week, home, back, return, night, m...
# 9  good, make, give, find, thing, hope, care, tur...
#
#                                                 Text
# 0   baltimore 20 september 1836 dear heinrich: fr...
# 1                  it was a long and arduous voyage!
# 2  however we were and are all well and thank the...
# 3  i had written down the events of the voyage fo...
# 4               as you know, we set sail on 12 july.
# 5  by the afternoon, when the pilot left us, one ...
# 6  the next morning i felt ill and remained in be...
# 7                         later i was always spared.
# 8  the wind was adverse from the very first eveni...
# 9  on the open sea things went fine in the beginn...

# %% [markdown]
# ## Most representative sentence for each topic

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# %%
# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.4460
# 1        1.0              0.4094
# 2        2.0              0.2767
# 3        3.0              0.3010
# 4        4.0              0.2469
#
#                                             Keywords  \
# 0  day, leave, week, home, back, return, night, m...
# 1  place, house, mile, large, water, town, high, ...
# 2  write, letter, send, long, time, hear, receive...
# 3  time, people, present, bad, meet, world, lose,...
# 4  child, dear, live, sister, feel, family, love,...
#
#                                                 Text
# 0  for your amusement, here's a typical week's me...
# 1  standing as we did on the top of an almost bal...
# 2  i wrote you a long letter in january 1866 givi...
# 3  excerpts from a speech made in the house of re...
# 4  god bless you my dear child, may wednesday pro...

# %%
print(sent_topics_sorteddf_mallet['Text'].values)
# Out:
# ["for your amusement, here's a typical week's menu: sun breakfast: bacon, eggs, creamed potato, raisins (no lunch on sunday) dinner: stuffed beef, beans, lettuce, rice, pickled cabbage, pudding mon breakfast: creamed potato, jam lunch: sandwich, lettuce, rice, applesauce dinner: pork and beans, radish, salad, raisins tues: breakfast: mush, apricot lunch: meatballs, rice, lettuce, pickle dinner: bologna, spaghetti, pickles, peas, pudding wed: breakfast: bran flakes, jam lunch: boiled beef, rice, lettuce, takuan dinner: salted mackerel, pickles, rice, peas, jello thu: breakfast: cornmeal, prunes lunch: salted pork and cabbage, beans, lettuce dinner: meatballs, rice, pickles, prunes fri: breakfast: bran flakes, jam lunch: cod fish, lettuce, rice dinner: liver, onion, lettuce, pudding sat: breakfast: mush, raisins lunch: curry-rice, salad, peach dinner: wiener, sauerkraut, rice, figs naturally, in addition, there is bread at each meal, coffee in the morning, and tea with the other meals."
#  'standing as we did on the top of an almost bald mountain, we could with one glance take in the whole panorama; the deep valleys in the foreground, densely wooded with dark firs, whose tops were many hundred feet below us; the tangle of chasm and precipices beyond some of the latter nearly bare, others covered with a growth of brushwood and stunted firs; the sides of the mountains furrowed by numberless ravines and gulches, and beyond this and towering high above it all, the mighty giants themselves, rising high above the line of vegetation, their sharp peaks glittering with eternal snow and ice standing out frozen and clear through the blue atmosphere.'
#  'i wrote you a long letter in january 1866 giving you all pirtuculars and my doughter elizah jane sent hur and hur sisters potogaph to youes and i requested anser from you with all the newes that you coud put in it, but up to the present i have go no anser to it, and brother joseph sent you one last spring and you never have ansered it neither; as i have sent you a great many long epistols about that country i wil say littel in this one: as we can have the newes of the day by the antlick cable in the course of a few houres; i have nothing in pirtuclar to mencion since i last wrout to you except the death of my second son joseph who died on the 15th of august last aged 25 years; he was in bad health for the last two years of which i gave you anacount of in my last letter and i sent you a newes paper in which his death was mencined the same week that he died.'
#  'excerpts from a speech made in the house of representatives, washington, d c, taken from records in santa fé: mr richard h weightman, representative of the territory of new mexico, 1852-1853, has this to say: "should i close my remarks without speaking in their behalf, (the natives of new mexico) i would be unmindful of the courtesies and kindness and hospitality i have invariably received in every part of new mexico, and be unworthy to represent people who, with frankness and confidence, have trusted me to represent their true condition and promote their interests and happinessi have never met in any part of the united states people more hospitable, more lawabiding, more kind, more generous, more desirous of improvement, more desirous that a general system of education should be established among them more desirous that the many and not the few, should govern, more apprehensive of the tendency of power to steal from the many for the few, more desirous of seeing in their own idiom the declaration of independence, the constitution of the united states, the history and words of the father of his country, the messages of presidents and state papers illustrative of the spirit and genius of our government.'
#  'god bless you my dear child, may wednesday prove a happy day for all parties, though absent i shall feel all your joy and ever remain you loving old mother susanna moodie'
#  'the following is a list of the provisions, &c, proper to be taken to sea for four persons, as steerage passengers: 16 or 18 pecks of potatoes, in a barrel with a lock upon it; 40 lb of good beef, well salted in brine, with a lock upon it; 16 lb of butter; 3 lb of coffee; 3 or 4 doz old bottled beer, which has less chance of flying than if new; some dozens of eggs, packed in salt; ½ doz cod fish, cut in pieces for boiling; some dozens of buckie haddocks, well dried for keeping; milk does not keep well; no sweetmeats are relished at sea; a few oranges, which at times taste very pleasant to the parched palate; some cheese; 8 lb of treacle, in a flaggon; 1 stone of barley; a good deal of pepper and mustard; plenty of carrots, turnips, and onions, for broth; they will keep all the voyage; 28 lb of fine ship bread; 8 or 10 quartern loaves, baked hard, from matthew; 1 boll of oatmeal, 6 pecks baked into bannocks and cakes, very well fired, and flat for packing; some white puddings; some suet for dumplings; a few candles, and a white-iron lantern with horn; 1 bottle of vinegar, to use in water on shipboard; 1 bottle of castor oil, and some ounces of colocynth and rhubarb pills; 6 lb of epsom salts and 1 lb senna; these medicines are very dear here; tin pan to fit the stove in the ship, and it is convenient to have one for hooking on the ribs of the grate, when the top of the fire is occupied; kettle for making coffee, &c n b use no crockery, but, in its stead, jugs and bowls of tin; broth pot, frying-pan, tin kettle.'
#  'now i beseech you, i conjure you, to do your utmost, your very best (for a great deal depends upon the care you take of yourself) that i may find you in good health, right hardy, strong, and in every respect well, for think not that i am exaggerating it would break my heart if i should, god forbid, find you otherwise.'
#  'that at the close of the poll on saturday, the last day of taking the same at the said election, your petitioner had a majority of votes; one hundred and three having polled for your petitioner, and only ninety-nine for the said william hamilton, as appeared by the poll-book kept by the clerk of the said election; and that the said joseph fortune, being such returning officer as aforesaid, contrary to his oath of office, as such returning officer, in gross violation of the rights of the people, and the privileges of your honourable house, and to the great damage of your petitioner, in a partial and arbitrary manner, immediately after the close of the poll, on the last day of the said election, without instituting any scrutiny into the legality or illegality of any of these votes, received and entered upon the pollbook at the said election, and without assigning any sufficient reason for such his arbitrary and vexatious conduct, did, corruptly and falsely, return the said william hamilton, and did declare him, the said william hamilton, to be duly elected, to represent the said counties of prescott and russell in this parliament.'
#  ' westminester december the 5 1853 my dear brother i take up my pen after the lapse of a few years to write to you and many of my old friends and neighbours who seem to be anxious to know how i ame and what i have been doing in america this informasion i have got in the letter you sent to brother josef from his son paul in austrilea and we were all glad to hear of him being on the land of the living and doing well; likewise to hear of your self and fameley at present thankes be to the giver of all goodnes for all his mercies to me and fameley; dear sir i shall commence by restaiting some of my former statements that is shortley after my arrivel in this country i bought two half acre bilding lotes in the town of london and likewise that i and brother thomas bought two hundred acres of land in the township of westminester; on my lotes in the town i bilt two houses one to live in and a leser one to rent this house rented at twelve pounds a year; nine years agoe i thought i would go to the country and improve my farm as there i intended to spend the better part of my life be my years many or few; so we removed to the country there i have been cutting down timber and burning it in the clearing of the land as much as would make a man rich if it was in ireland as you have heard so much a bout the clearing of the land in canady that i need not trouble you with a discripsion of it after a few years in the countrey i thought it better to sell the house that i lived in london and invest the price of it in buying more land and improving the farm that i live on; so i have bought 87 more acres 30 of it cleared and fenced this farm corners the one i live on; i have got 66 acres cleared on the farm that i live on which makes me owner of 187 acres of land with 96 acres improved free of any incumbrance as we hav no rent collectres coming half yearley to our door to a noy us no end to my leas; we pay a tax yearley which goes to the improvement of the roades my tax is this year 8 dollours or 2 pounds; i have got a good deacent frame house deacentley fineshed and barn with other stabling for my cettel the barn is 50 feet long by 30 feet wide and 16 feet high in the side; in thisg i store my grain as it comes of the harvast field this saves a grat dale of trouble in the stacking we trash our grain all trashed by mashenery; the one most in esteme in this part of the country is a two horse tread mashene the two horses that workes the mashene drawes it wright into the barn as our barns is so bilt that we can drive right through with a span of horses and wagon with any load for the convenicency of storing the grain; the floor is in the center this mashene trashes and separates the straw from the wheat and the wheat pases into the faning mill and comes out clean fit for the mil or market this costs me four doulours per hundred bushel; and the will trash from 100 to 150 bushels per day; the dwelling house and barn i have ensured for two thousand dollours that being two thirds of the supposed vallue of them this amount i would get if the were destroyed by fire; or supposed a part of them was destroyed i would be paid in proporsion to the amount of dammage done this costs me three dollours a year; i planted out a bout an acre with fruit trees such as apples pears plumes peaches cherries these all do as well in this country as i ever saw them in ireland if not better our verieteys are very good the trees groo quick and bear soon i have had about 60 bushel on mine this season i allso carry on a flour and vegible garden all of which do well in this country we have a great many kinds of both that woud not grow in ireland; farm stock of all kinds do well in this country and is very healthey i have had none that died of bad health in nine years that i have been farming in canada onley one pig and 2 sheep my flock of sheep number from 40 to 60 and pigs a bout 20 i keep a span of horses mostley maires from these i raise foales this payes well as horses sell wel i ...

# %%
# Number of sentences for each topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()
topic_counts
# Out:
# 0.0    7004
# 4.0    5413
# 2.0    5406
# 8.0    4744
# 1.0    4505
# 6.0    4501
# 3.0    4303
# 7.0    4167
# 5.0    3982
# Name: Dominant_Topic, dtype: int64

# %%
# Percentage of sentences for each topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_contribution
# Out:
# 0.0    0.1591
# 4.0    0.1230
# 2.0    0.1228
# 8.0    0.1078
# 1.0    0.1023
# 6.0    0.1022
# 3.0    0.0977
# 7.0    0.0947
# 5.0    0.0904
# Name: Dominant_Topic, dtype: float64

# %%
# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']].drop_duplicates().sort_values(by = 'Dominant_Topic')
topic_num_keywords
# Out:
#     Dominant_Topic                                     Topic_Keywords
# 4              0.0  day, leave, week, home, back, return, night, m...
# 0              1.0  place, house, mile, large, water, town, high, ...
# 16             2.0  write, letter, send, long, time, hear, receive...
# 23             3.0  time, people, present, bad, meet, world, lose,...
# 48             4.0  child, dear, live, sister, feel, family, love,...
# 11             5.0  bring, small, hand, put, fine, foot, carry, op...
# 1              6.0  good, make, give, find, thing, hope, care, tur...
# 2              7.0  work, man, great, call, school, order, person,...
# 27             8.0  year, country, land, money, dollar, pay, state...

# %%
topic_num_keywords.reset_index(drop=True, inplace=True)
topic_num_keywords
# Out:
#    Dominant_Topic                                     Topic_Keywords
# 0             0.0  day, leave, week, home, back, return, night, m...
# 1             1.0  place, house, mile, large, water, town, high, ...
# 2             2.0  write, letter, send, long, time, hear, receive...
# 3             3.0  time, people, present, bad, meet, world, lose,...
# 4             4.0  child, dear, live, sister, feel, family, love,...
# 5             5.0  bring, small, hand, put, fine, foot, carry, op...
# 6             6.0  good, make, give, find, thing, hope, care, tur...
# 7             7.0  work, man, great, call, school, order, person,...
# 8             8.0  year, country, land, money, dollar, pay, state...

# %%
topic_num_keywords = topic_num_keywords.reindex([0,4,2,8,1,6,3,7,5])
topic_num_keywords
# Out:
#    Dominant_Topic                                     Topic_Keywords
# 0             0.0  day, leave, week, home, back, return, night, m...
# 4             4.0  child, dear, live, sister, feel, family, love,...
# 2             2.0  write, letter, send, long, time, hear, receive...
# 8             8.0  year, country, land, money, dollar, pay, state...
# 1             1.0  place, house, mile, large, water, town, high, ...
# 6             6.0  good, make, give, find, thing, hope, care, tur...
# 3             3.0  time, people, present, bad, meet, world, lose,...
# 7             7.0  work, man, great, call, school, order, person,...
# 5             5.0  bring, small, hand, put, fine, foot, carry, op...

# %%
# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts.rename('counts'), topic_contribution.rename('contribution')], axis=1).sort_values(by = 'Dominant_Topic')
df_dominant_topics
# Out:
#    Dominant_Topic                                     Topic_Keywords  counts  \
# 0             0.0  day, leave, week, home, back, return, night, m...    7004
# 1             1.0  place, house, mile, large, water, town, high, ...    4505
# 2             2.0  write, letter, send, long, time, hear, receive...    5406
# 3             3.0  time, people, present, bad, meet, world, lose,...    4303
# 4             4.0  child, dear, live, sister, feel, family, love,...    5413
# 5             5.0  bring, small, hand, put, fine, foot, carry, op...    3982
# 6             6.0  good, make, give, find, thing, hope, care, tur...    4501
# 7             7.0  work, man, great, call, school, order, person,...    4167
# 8             8.0  year, country, land, money, dollar, pay, state...    4744
#
#    contribution
# 0        0.1591
# 1        0.1023
# 2        0.1228
# 3        0.0977
# 4        0.1230
# 5        0.0904
# 6        0.1022
# 7        0.0947
# 8        0.1078

# %% [markdown]
# ## Append topics to sentiment dataframe

# %% [markdown]
# This code is adapted from the work of Sunyam Bagga in Moody, A., & Bagga, S. (2020, July 22-24). A comparative study of sentiment and topics in migration related tweets. Digital Humanities 2020 Conference, Ottawa, ON, Canada. https://dh2020.adho.org/wp-content/uploads/2020/07/725_Acomparativestudyofsentimentandtopicsinmigrationrelatedtweets.html

# %%
# Create dictionary
map_sentenceText_topicNumber = {}

# Loop through sentences and get topics
for index, item in enumerate(data):
    topic_dist = mallet2ldaModel_09.get_document_topics(corpus[index])

    # topic_dist is a list of tuples: each tuple has a topic number with its corresponding proportion
    sorted_topic_dist = sorted(topic_dist, key=lambda x: (x[1]), reverse=True) # Sort it in descending order
    
    # Pick the top (main) one and put it in the dictionary:
    topic_number = sorted_topic_dist[0][0]
    map_sentenceText_topicNumber[item] = topic_number

# %%
map_sentenceText_topicNumber
# Out:
# {' baltimore 20 september 1836 dear heinrich: friday evening, 16 september, anchor was dropped and we had safely arrived in the harbor!': 1,
#  'it was a long and arduous voyage!': 6,
#  'however we were and are all well and thank the father in heaven that he has protected us so far!': 7,
#  'i had written down the events of the voyage for you, but to my great annoyance i am now missing the whole notebook; perhaps i will find it later.': 6,
#  'as you know, we set sail on 12 july.': 0,
#  'by the afternoon, when the pilot left us, one after the other began to hold his head overboard; bernhard, mrs schwarze, the children, and others.': 7,
#  'the next morning i felt ill and remained in bed for two days, but during the whole time i only had to vomit four or five times; this was pretty much the same with most passengers.': 0,
#  'later i was always spared.': 6,
#  'the wind was adverse from the very first evening and remained so for almost three weeks; we did not pass the english channel until 2 august and had to cope with very heavy stormy weather in the north sea.': 0,
#  'on the open sea things went fine in the beginning; later we sailed southward and experienced a calm and great heat.': 6,
#  'the longing to reach land as soon as possible became greater and greater.': 7,
#  'the water was very bad, and the food was not very appetizing; how good that we had ham and sufficient wine with us.': 5,
#  'but there were lots of other things lacking.': 6,
#  "how i pitied others when i dined with hermann at noon in the captain's cabin, and also when the heat was great and we sat down beside mrs kirchberg.": 0,
#  'there was scarcely any other shade on deck.': 0,
#  'mrs ossenbeck from everswinkel was happily delivered of a son; bruns was in attendance.': 7,
#  'he was baptized by the chaplain and received the name johann heinrich bruno ulysses.': 2,
#  'the godparents?': 1,
#  'captain j h spilker and mrs bruns.': 0,
#  'a festive noon meal followed, in which schniederjans and i participated.': 0,
#  'we saw only a few fish.': 5,
#  'once a dolphin was caught and provided us with beef steak for two days; at least it could hardly be differentiated from beef.': 5,
#  'otherwise the trip was very monotonous.': 6,
#  "great was everybody's joy when the pilot ship approached us at cape charles.": 3,
#  'it was late the evening of the 12th when we entered the bay.': 7,
#  'and then there was another calm and we often had to lie at anchor.': 1,
#  'saturday, the 17th, after the doctor had left the ulysses, the three cabin passengers, bruns, and i with hermann, rienermann, wenker, mallinckrodt, schwarze, and lücke were put ashore.': 0,
#  'we were very sincerely happy to have firm soil under us and hurried here.marginal note: we immediately went and bought fruit and everything tasted magnificent.': 8,
#  'we spent the night here.': 0,
#  'on sunday morning we went with hermann to the cathedral (jenne was still aboard).': 0,
#  'i was deeply moved when i found myself in the really beautiful church, and i was able to tell the good lord so very much from the bottom of my heart in a few minutes.': 6,
#  'the church was empty; we were told that mass would be held in an hour.': 1,
#  'therefore bruns and mallinckrodt went to the bank; the chaplain and a few steerage passengers had, as they later told me, gone to a german catholic church.': 5,
#  'hermann and i had to wait patiently during this hour.': 0,
#  'finally it was time!': 2,
#  'it was a musical mass.': 0,
#  'the sexton or assistant accompanied me to a bench otherwise all belonged to private people but bruns had to stay in the back with hermann, as i latter realized.': 0,
#  'that made me uneasy and i looked around several times, and suddenly both of them were gone.': 6,
#  'the gospel was read, and since we could not understand it, we went home and hermann was spared.': 7,
#  'by then franz, bernhard, david, and viele, who had all hurried to mass after the quarantine had elapsed, were also here.': 0,
#  'i do not like it here in baltimore; i have never known such heat as we have had in these days.': 0,
#  'it was not possible to write earlier because i could not collect any of my thoughts.': 2,
#  'hermann causes me a great deal of trouble, and bruns and the brothers are always busy.': 0,
#  'yesterday morning they all left except for bruns and me, hermann, mallinckrodt, wenker, and rienermann.': 0,
#  'the canal from philadelphia to pittsburgh is not passable, and thus the goods had to be transported by wagons.': 0,
#  'franz and bernhard have bought linen jackets and straw hats and, with a rifle on their backs, roam the country with the other hunters if they are not in the mood to sit on the slow freight wagons, onto which seats have been attached.': 0,
#  'i would very much like to be with the others, but bruns did not want to leave me alone, and thus tomorrow we will travel to philadelphia and new york.': 0,
#  'i shall write again in a few days, but i would like to give wings to this letter because you will certainly be waiting for it.': 2,
#  'a thousand greetings to all, especially to the brothers and sisters and relatives.': 4,
#  'how often i thought of you on the desolate sea voyage.': 5,
#  'i shall write more details in another letter.': 2,
#  'the brothers will hardly be able to write before we reach our property.': 2,
#  'once more greetings to the brothers and sisters, and to all the others from us.': 4,
#  'your sister jette, who loves you sincerely.': 4,
#  ' tuesday, 14 november 1836 dear heinrich: we arrived here at eleven in the morning on all souls day.': 0,
#  'the log cabin was locked up, but bruns broke the lock.': 5,
#  'it consists of one room the size of our living room with one window; in it there were a table, four chairs, and two bedsteads.': 5,
#  'so this was to be our home for the winter!': 0,
#  'i have to confess that i nevertheless felt good to have reached a safe asylum, and very uplifted by the firm knowledge that i want to stand everything with fortitude.': 4,
#  'the sun shone warmly and kindly through the leafless trees; soon a bright fire was burning, and for the noon meal we had some wonderful vegetables.': 1,
#  'our belongings could only be transported very slowly, and thus in the first week we lacked all kinds of things; however, i still am happy that with every day things will become better.': 0,
#  'now the carpenter kolk has built a shed onto the house in which the boxes can be stored.': 1,
#  'our possessions, with the exception of a few things, arrived in good shape.': 6,
#  'unpacking and airing things is a lot of work.': 8,
#  'our next-door neighbors are huber, hesse, nacke, and gramatica, whom i have visited with bruns.': 5,
#  'last thursday and friday we had divine service.': 7,
#  'a dignified young jesuit (who is a native of cleve) read the mass, and all received holy communion.': 2,
#  'in counting the catholic community we arrived at seventy members.': 7,
#  'only bruns and i could go to mass on the second morning.': 0,
#  'the rain poured down from heaven in buckets; it was a hard walk.': 0,
#  'after confession mr huber was married, and then the mass began.': 7,
#  'we had coffee at the hesses and started on our way back, but we almost got stuck.': 0,
#  'the water had gathered so much that we had trouble getting through.': 1,
#  'if by next summer we have a horse i shall certainly be able to use it; however, bruns will probably have to buy one sooner because he has to get out almost every day.': 8,
#  'the americans seem to have a great deal of confidence in him.': 3,
#  'if bruns is not at home and an american comes, then, my dear heinrich, it is a joy to see how beautifully we endeavor to speak english.': 3,
#  'it is really my greatest annoyance that i cannot use it.': 6,
#  'however, it will soon improve.': 8,
#  'on the first sunday we were at the hubers for lunch, along with another gentleman.': 0,
#  'in the course of the conversation he explained that he could not at all understand the lady in our house.': 0,
#  'lady jenne!?': 0,
#  'we really had a good laugh at this.': 6,
#  'she, by the way, had a great deal of fun in getting this title.': 2,
#  'sunday, 3 december still no letter has been dispatched to you!': 2,
#  'it seems to me that this delay is not quite right, although bruns said that one really could not write until the germans who had come with us had established a permanent place.': 1,
#  'i, however, think you will give us the first priority, and your sympathy will demand news from us.': 2,
#  'during this time we all have been very busy.': 0,
#  'we have done our laundry, a hog was butchered, corn had to be harvested, etc for approximately ten days now, and to my great joy, franz and bernhard, who had stayed with the hubers until then, have been with us.': 8,
#  'heinrich niedieck went from us to an american by the name of burns.': 1,
#  'he visited us today again, and he is quite satisfied.': 2,
#  'he is most likely to be the quickest to learn english.': 7,
#  'now today we have rainy weather again, the third time since we have arrived here; for two weeks we had a freeze.': 0,
#  'it froze pretty heavily during the night, but during the daytime it always turned very pleasant and the sun shone warmly as it probably never did in westphalia so late in the year.': 6,
#  'when it rains, it is just too sad in these log cabins; the one in which we live lies on a slope, and thus a little ditch had to be made so that the water would not run into the shed and even into the house.': 1,
#  'in cold weather one is a little hesitant to get up in the morning, and i frequently think back to our comfortable living room.': 0,
#  'however, here we just have to live through it.': 4,
#  'there is one situation that makes me very cross.': 3,
#  'it is that jenne is not at all adaptable.': 5,
#  'the thought that i will have to get along for years with this disorderly, clumsy person can discourage me any moment.': 7,
#  'too often i am vexed about this, and i believe that she is a hopeless case.': 7,
#  'thus it happens that i myself have to do most of the cooking and have to try to find work for her outside the house if possible.': 6,
#  'i shall commend this cross to heaven!': 4,
#  'you cannot believe how satisfying it is to work.': 0,
#  "i probably have had few days in which i was ever as busy as i am here, that is, having to do hard work, but i'm quite happy in doing it, and like all the others i have a tremendous appetite and sleep soundly.": 0,
#  '(it is strange, but almost every night now i dream of our father, and then i am still a child with him and spend beautiful hours in my dream.)': 0,
#  'during the first days of our stay here hermann was unwell and had fever every day.': 0,
#  'soon, however, it dissipated, and the little rascal is very frisky and has a much greater appetite than ever before.': 7,
#  'when the weather is good he roams around outside.': 6,
#  "franz will probably take over the farm on which we now live from bruns's brother because it is more adaptable to another business.": 4,
#  'the connection from the osage to the missouri river and back is easier here, and hermann bruns will move about three miles away from us, where he has bought an improved farm from an american by the name of russet.': 4,
#  'david bruns will be situated a little closer to us.': 1,
#  'he will buy some government land.': 8,
#  'in the next few days, after the corn has been harvested here, bernhard will go to mr scheulen, who has a mill and distillery.': 8,
#  'he is really itching to go.': 3,
#  'i have not yet seen very much of this whole area; however, the location of our farm is very pleasant, and the place where the house is going to stand is the best of all the locations.': 1,
#  'yesterday i went there with bruns in order to discuss a few changes concerning the construction of the house with kolk.': 3,
#  'we will take two rooms less and instead will have a hall.': 0,
#  'if only we could be moved in!': 3,
#  'who knows what will happen in the meantime!': 7,
#  '[continued with red ink] i hope that we will soon be able to call for a letter from you from the post office, for you certainly will have remembered that you wanted to write at the beginning of september.': 2,
#  'i yearn very much to hear from you, although i am for the time being at peace concerning you.': 2,
#  'quite frequently we talk about where you might be at this time, in bonn or heidelberg?': 2,
#  'surely you will have passed the final exams long ago while we were still rocking on the high seas.abiturgymnasiumabiturpaulinum it is disagreeable to us that letters cannot be sent directly to you; however, the uncles will surely forward them to you immediately.': 2,
#  "franz is sitting here with us and talking a blue streak and says i should write about this since i'm complaining about it: bernhard is talking while he is lying in bed.": 2,
#  "old schwarze's fritz, who lived in shipley's log cabin with vennewald, has bought some land approximately six miles from us between the maria and the missouri, eighty acres of land, of which twelve have been cleared and are planted in corn, for which he paid two hundred dollars.": 8,
#  'they all say that he lives too far away; however, he himself is mightily satisfied and is already living there and has taken over horses, cows, pigs, geese, and chickens valued at four hundred dollars.': 8,
#  'vennewald came back only yesterday, from st louis, where he filed for eighty acres of government land.': 8,
#  'hessler has also gone there in order to buy land.': 8,
#  'he will live approximately eight miles up the maria from us.': 1,
#  'fritz schwarze am teich is also in st louis and will file with hessler; they say that if he lives there and wants to operate a distillery, he will not have such a good market there as compared to here.': 3,
#  'rienermann is still with the hesses, but he will probably soon move on.': 3,
#  'zellerhoff is working at the clarenbachs every day for one half dollar plus board, just as westermann is.': 8,
#  'some who really have great plans say that we are living too close to our neighbors, which will be detrimental for raising stock, and this is also the reason why h bruns (as a capable farmer) will move farther away.': 8,
#  'but we are a good fifteen minutes away from our new house, and almost the same distance from the hubers and hesses.': 1,
#  'gramatica will probably be situated closest to us, but it seems to me that fifteen minutes is far enough to let a herd of pigs run wild.': 1,
#  'franz and several other think likewise.': 8,
#  'by the way, we are unlikely to do any farming to any great extent the medical practice is better.': 8,
#  "bruns's two brothers live in the other house, as do the carpenter kolk and jan, who formerly was a hired hand with bruns in lohne.": 4,
#  'my husband has hired him for a year, and since he has some experience he is helping kolk with the construction of the house.': 8,
#  "kolk's fiancée, who is staying with us until the wedding, cooks in this house.": 0,
#  'now i want to tell you good-bye, and i shall soon write more.': 6,
#  'you will have received the first letter from new york.': 2,
#  'greetings to all, especially to the brothers and sisters, to the uncles and aunts a thousand times; also the brothers and sisters geisberg, the boners, lena, trude, and all our acquaintances!': 4,
#  'so many times i think of you back home!': 0,
#  'later when we have more peace we shall report in with more letters.': 2,
#  "you certainly are corresponding with johanna, with wilhelm and threschen, aren't you?": 3,
#  'do write me about them all, everything you know.': 2,
#  'i am thinking of sending a few enclosures for them in the next letter.': 2,
#  'do keep up the good relations with them!': 6,
#  'they have to feel very close to you!': 4,
#  'and now dear, dear heinrich i hope you are well.': 0,
#  'i am beginning to realize how great the separation is!': 7,
#  'do not study too hard and do take some time for recreation and be careful with the wild activities of students.': 3,
#  'you have to answer me right after receiving this letter!': 2,
#  'franz, bernhard, bruns, and hermann send their sincere greetings, together with your loving sister, jette.': 4,
#  'on 3 march 1837 jette wrote to her aunt therese and uncle adolf geisberg to announce the arrival five days before of her second child, max, a healthy boy "with a stub-nose and little black hair."': 5,
#  'she had not yet heard from her relatives.': 2,
#  'the letter is completed by dr bruns, who reports that jette is feeling very strong.': 2,
#  'he is highly satisfied with her condition.': 4,
#  'the immigrants from westphalia are doing well in the new world, with fine plantations and good prospects.': 6,
#  'he has a lucrative practice, but "the one thing we lack is good company.': 6,
#  'this is particularly unpleasant for the women ."': 4,
#  'on 5 march, franz geisberg wrote to his uncle caspar, reporting that he had bought eighty acres of land bordering that of bruns.': 8,
#  'on 14 april, bruns wrote caspar of his land holdings on the maries, the livestock he had acquired, and his successful practice.': 8,
#  '"i wish you could see our property here.': 8,
#  'you would exclaim!': 2,
#  'here is a good place to live!': 6,
#  'the location is like paradise.': 8,
#  'the soil cannot be worn out."': 8,
#  'the winter had been quite unfriendly, but spring was arriving and everything seemed well in the westphalia settlement.': 0,
#  'on 30 may, bernhard geisberg wrote to heinrich of his trip from baltimore and the arrival on the osage, "the most beautiful river which i have yet seen in americasome maintain it is the most beautiful river in the united states."': 1,
#  ' westphalia settlement august 1837 dear heinrich: today i was alone all day long with my little ones.': 2,
#  'and i thought that i would write you a lot.': 8,
#  'i talked with you in my thoughts all morning.': 0,
#  'but here comes an american on horseback, and i have to try to speak english with him.': 1,
#  'he is waiting for bruns, who will not return until this evening.': 0,
#  'i have progressed with my english speaking so far that i can understand occasionally a few common little sentences and can reproduce them.': 7,
#  'i must really learn more, for it annoys me tremendously when i stand there like a blockhead and cannot answer.': 7,
#  'i am being admonished by you and by uncle caspar to write more.': 6,
#  'bruns is to be blamed that i have not answered the letter i received on 2 july until now.': 2,
#  'i had sat down a few times and had already written more than a page when my husband happened to read the letter and announced his verdict that it was not worth a penny.': 2,
#  'at first, i was absolutely furious, but then i thought it over and found that he was not quite wrong.': 6,
#  'it bears the imprint of my mood at that time.': 3,
#  "i had to force myself to put something down on paper; and therefore there's almost not a healthy thought in it.": 5,
#  'now, however, only now, i shall and can write anew, but i must humbly ask that you do not immediately judge me.': 2,
#  'on 2 july, i received the first letter from you.': 2,
#  'it was the second you had written, dated april 8th (therefore the first one is somewhere else).': 2,
#  'the time before receiving it was dragging on, and i was restless, especially since i counted on your punctuality.': 2,
#  'your letter was in many ways quite touching for me.': 2,
#  'i often think of cousin johanna.': 0,
#  'it was somewhat puzzling to me that our johanna has already gone to stromberg; that, i thought, would be better at a later time.': 2,
#  'if a fine education is missed in these years, then it is hard to make up for it later, and i find it hard to believe that miss költchen accomplished this in one year.': 6,
#  'if there should be some change in her situation, then take care that special consideration is given.': 3,
#  'fritz schwarze, who left here in june, had not received a letter from dina f, and even now none has arrived.': 2,
#  'it does not seem to me to be quite right if she wants to change her mind.': 7,
#  'we are quite anxious to know and would hate to lose him.amphitrite300 jahre brennerei-tradition in einer west-fälischen familie heinrich niedieck received a lot of letters recently, specifically a bank draft; everything was addressed to bruns.': 2,
#  'he was very happy at this.': 4,
#  'he has to be treated with circumspection; he is not yet well.': 4,
#  'it is a shame that the address on the newspapers sent to osterlink had gotten lost; it could easily have turned out that it was not bruns who was the writer.': 3,
#  'well, our mr brother does a little teasing, which really made me laugh heartily, and even little max laughed and thought it would be high time that the faraway uncle learns of his arrival if he had received his name.': 4,
#  'if the heavens will consent and will bless us further we shall let it be known in time so that you can assist us in praying for a little johanna.': 6,
#  'brother bernhard has been in new dortmund on the missouri since the beginning of june to work in the tannery belonging to mr wenker, our former traveling companion.': 7,
#  'he has not yet written; however, i have copied your letter for him and also admonished him to write.': 2,
#  'franz is with us.': 0,
#  'i really think he will have to live for a while among the americans to learn english.': 4,
#  'in his leather pants he really looks like a farmer.': 8,
#  'aside from a little slowness, he seems to me to be doing well and seems to get along fine with his work.': 4,
#  'our household consists of franz, bruns, me, with my two boys, jenne and drüke, kolk and wife, big jan brüggink, little jan hillen, and david bruns.': 2,
#  'hermann bruns has gone to st louis to spend some time there.': 3,
#  'for two weeks now three rhinelanders have been making bricks, so david and little jan are always here.': 1,
#  'we have had very little luck with anything that we have tackled this year, and it takes a great deal of perseverance and patience not to lose courage.': 3,
#  'you know that we believed we would be able to occupy our house soon after our arrival.': 1,
#  'but still only the skeleton is standing, and a few shingles have been attached to indicate how the roof will be.': 1,
#  'our carpenter, to be sure, has done his work well, but has proceeded so very slowly that the entire world is amazed.': 3,
#  'the shingles are being cut by someone else.': 7,
#  'in the bottom, down below the new house, there is a small field and a pasture for the cattle.': 8,
#  'however, we did not get around to finishing that, and so the field has remained almost desolate.': 5,
#  'the few things that have been planted have been destroyed by the flood.': 1,
#  "here on franzen's farm we planted two-thirds in corn and one-third in wheat.": 8,
#  'the corn stand is good, so we hope the corn will ripen, although it has received very little care.': 6,
#  'in the spring our horses suddenly got sick and we could not plow, and the weeds got out of hand, and so the corn had to be hoed, which was very troublesome and was not completed.': 8,
#  'the wheat grew very poorly and had to be stacked in a big pile since we still have no shelter for it.': 1,
#  'we could plant only very few vegetables because the little fellow took too much of my time.': 8,
#  'the few things on the stiff upper land did not succeed very well.': 6,
#  'now we have many people and little to eat.': 3,
#  'a great worry for the housewife!': 3,
#  'fresh potatoes have to be dug now, so that there is something here.': 5,
#  'in order to make the misfortune complete, our carpenter and his young wife were hit by the fever; jenne now has been going there every morning for a week to cook and take care of the household.': 6,
#  'well, what else should i complain about?': 2,
#  'that i am very often vexed?': 3,
#  'that i feel doubly annoyed with all these misfortunes and the domestic annoyance with jenne etc etc?': 3,
#  'that it is no fun to represent cook, nursemaid, and housewife in one person?': 6,
#  'away, away, with further song concerning these things.': 3,
#  'to say it in brief, i wish and hope that things will improve!': 6,
#  'my boys sweeten many a disagreeable thing for me; unfortunately the big one has already begun to be quite unruly, but when that is past i really love him very, very much.': 2,
#  'and the little one is a complete little angel.': 8,
#  'all day long he is friendly, but he does not want to sit or lie down, and i always have to hold him.': 0,
#  'with his bare little head with the golden brown hair shining, lightly dressed, often wearing only a little shirt, he mumbles loudly with a strong voice and approaches hermann, then looks at him cheerfully, and the latter jumps in front of him and makes him laugh loudly.': 5,
#  'bruns also pays a great deal more attention to max than he did earlier to hermann; he is probably now used to them.': 8,
#  'also, the good man has far more consideration for me; he probably thinks that i am now in greater need of it.': 7,
#  'when i express a wish, he seeks to fulfill it.': 3,
#  'his practice is a little too far, even though it earns that much more; today he is away in portland on the missouri, which is thirty-five miles from here.': 1,
#  'a week ago i went for the first time to the schwarzes.': 2,
#  'franz took us there because bruns was out.': 0,
#  'he has good corn, his wife has a clean household, she is active, and her lisbeth is no less active; it makes me sad when i see how the latter assisted the mistress constantly, and jenne has such a tremendous deliberateness when i struggle in her presence.': 6,
#  '(bruns said that as soon as possible he wants to buy me a black girl, whom i could then teach.)': 2,
#  'the way to the schwarzes, through lisletown, is really not too far.': 6,
#  'i really had to laugh aloud at his ability to build; a very pretty fireplace, a kitchen, and a strange outhouse have been finished.': 0,
#  'really these people become extremely skilled here.': 3,
#  'now i have to close.': 5,
#  'in the next few days i shall write a letter to you and send it by way of münster, and later i shall write regularly every six weeks myself, or franz, or bruns.': 2,
#  'you mention very little of wilhelm and thereschen, tell me a little bit more of them the next time, and they also all have to write me.': 2,
#  'greetings above all to the brothers and sisters; i hope they write you frequently because you have to know exactly what is happening with them.': 4,
#  'they have to give you their complete confidence.': 8,
#  'do write whether i can send a letter now and then to bonn.': 2,
#  'and now farewell!': 0,
#  'write frequently, even if it is only small details of what you do on this or that day, and then embellish it a little bit because i like that so much; and repeat a few things from the first letter which was lost.': 2,
#  'hold dear, as always, your faithful sister jette.': 4,
#  " westphalian settlement 7 september '37 dear heinrich: at the beginning of august i sent my last letter to you.": 2,
#  "i've also sent a few pages to johanna, which i gave to schwarze to take along.": 2,
#  "it's little enough; however, it is getting better and better, just watch!": 3,
#  'a quarter of a year ago now a very beautiful piece of furniture, which outshines all other items, a piano, found its way into our log cabin.': 5,
#  '(but perhaps you know this already, since bruns has written to uncle caspar about it.)': 2,
#  'what a strange coincidence!': 0,
#  'how could i have imagined that just such an instrument as i had denied myself would be made available to me in america!': 6,
#  'until a few days before the departure of the hesses we had not thought of it; then the hesses offered it.': 8,
#  'german price, german work, without the cost of transportation!': 8,
#  'thus we agreed.': 0,
#  'however, i have to confess that the beautiful piano neither has a suitable place nor is it being properly used.': 1,
#  'both will be taken care of better in the new house.': 6,
#  'it has a beautiful full sound, and the outside has brown finish; there is nothing lacking.': 5,
#  'the swede, mr blumenthal, was recently kind enough to tune it.': 4,
#  'the guitar kept very well on the trip.': 6,
#  'mr hesse you mentioned him started his return trip to europe in the spring.': 0,
#  'a few weeks later he wrote to bruns: in st louis his brother, who had been ill here for a long time, died.': 2,
#  'later, on the train between lancaster and philadelphia, he lost his only little son; his wife was twice at the edge of her grave; however, she has recovered in the meantime, so he wants to embark for england.': 3,
#  'thus he leaves america.': 0,
#  'mr hesse came with great expectations; he brought along many people, and only average means.': 3,
#  'the people did not do what they were supposed to do, and his wife was not in accord with them; from domestic dissension there developed disgust; the people drifted away, mr hesse toiled honestly in his field, but he alone, with his quick temperament, could not accomplish enough.': 3,
#  'the children were not directed to do anything; the mother lived only for her children and wished nothing more than to return.': 4,
#  'and here sat mr hesse, without means, without help, without a prospect.': 8,
#  'it is true that only after long resistance did he decide to give in finally to the will of his wife.': 2,
#  'perhaps in the end he secretly longed to return himself; however, without the strong urging of the latter he probably would never have decided to do it.': 0,
#  'he seemed to fear the return to germany.': 3,
#  'i still see his sad, quiet face in front of me; in the last weeks he was extremely depressed.': 7,
#  'he did have weaknesses and faults, but he always remained a man worthy of respect.': 3,
#  'envy can never take this name away from him, nor jealous ingratitude; nor the verdict of the jury.': 4,
#  'he returns over the ocean with a spotless reputation.': 1,
#  'we were very sorry that he did not satisfy the probably irresponsible claims of his former domestic help, but departed quietly from st louis.': 0,
#  '(he was not able to say no to anyone who asked for anything.)': 0,
#  'the state of health of the family did not allow him to seek justice publicly, nor perhaps did his already limited means.': 3,
#  'you see, we are inclined to think the best of him, as most of the others around here do.': 6,
#  'his farm has been taken over by a rhinelander, a straightforward, simple man who, for the time being at least, makes us miss the former owner very much.': 8,
#  'there are fewer educated people around here than former country people, who probably for the time being will have the best of it.': 3,
#  'a great deal of patience and perseverance are necessary in the beginning; otherwise i am afraid that mrs hesse will find all kinds of women who will follow her back.': 6,
#  'among the educated people we would count the family huber, which consists of husband, wife, mother-in-law, and brother; niedieck is also in their house; further, the family clarenbach; the husband is in germany at the present time, and i hold the wife in high esteem; she has three children and two brothers and a sister (a grown brother, the sister is smaller than johanna).': 4,
#  'then in lisletown there is mr menges, a merchant, and on the osage there are a few swedes who have a store, and very fine people by the name of gramatica, the schwarzes, and linnemann here on the maries, and thus it goes on.': 3,
#  'in the middle of june we had a considerable flood here.': 8,
#  'the entire bottom along the maries was under water, as was that along the osage; we have heard that the ohio was extremely high.': 5,
#  'all the little pigs floated away, and many hogs died.': 8,
#  "we ourselves had our new and franzen's small field under water, and then we had to collect our split rails that were scattered in the woods and lug them back, and we also lost a few shingles.": 1,
#  'that was not much damage.': 5,
#  'our corn remained in good condition.': 3,
#  'some, however, who lived near the maries had to evacuate their houses and lost most of their corn and their garden fruit.': 8,
#  'our drying house for the bricks was soon repaired, and now approximately thirty thousand bricks are dry but have not yet been fired.': 5,
#  'i am full of anxiety and worry that the weather will change; otherwise they will be finished a week from today.': 2,
#  'and then the bricks will be laid, and as soon as the walls are there we will be able to move.': 1,
#  'i wish you could share my longing; we have to get there at any cost.': 8,
#  'up there on the hill it is so airy, it will dry quickly; it will be a lovely spot where i shall feel at home again.': 1,
#  'oh, how many annoying hours have i spent because of procrastinations; how slowly everything progressed with this carpenter; i would like to have the patience of an angel.': 0,
#  'but is it not really terrible that we have been building here now for two years?': 8,
#  'i can scarcely think of anything else, but have so much to worry about, and nothing has helped.': 3,
#  'bruns is also quite glum.': 4,
#  'we are now firmly resolved that in case the bricks should fail we will make a few mud walls and move in anyway.': 1,
#  'we just cannot go on as we are now!': 0,
#  'there is one other thing i want to tell you.': 6,
#  'do you know that i also ride a horse?': 8,
#  'on the 4th of july i rode on a brand new side saddle to the scheulens.': 5,
#  'max was sitting very happily in my lap.': 4,
#  'there were several americans and germans there, and the noon meal took place in accordance with the american way.': 1,
#  'at first all ladies sat down, and several gentlemen served us.': 0,
#  'soon after the meal there was some dancing.': 2,
#  'but there was only one fiddle there.': 3,
#  'american dancing is really quite boring, without a beginning and without an end, almost like contre dances but with no different couples.': 5,
#  'finally they figured out that one could also waltz to the tune; and i even danced around a few times.': 4,
#  'in the end it almost turned too dark for us.': 6,
#  'a few weeks ago a camp meeting took place near the post office.': 0,
#  'it lasted for over three days and is said to have been very crowded.': 0,
#  'in the beginning we also intended to go there; however, after some consideration, we thought it better to remain at home.': 2,
#  'franz rode over there.': 0,
#  'some women became enraptured, others moaned mightily (this is a special sign of reverence), others wept.': 4,
#  'there is constant preaching.': 6,
#  'when hunger calls, then food is served under the tents that have been pitched, and all who are at all known are invited to partake.': 5,
#  'for three days, mr bensink (from bielefeld) ate busily, drank, moaned, and shouted amen, but delayed his further conversion somewhat.': 0,
#  'americans who do not believe in anything nevertheless ride there, shake their heads, and smoke, talk, chew, etc, which does not particularly please the preachers, who often have to ask them to quiet down.': 5,
#  'we have also had some very warm days here, warmer than i have ever experienced, but not so sultry.': 0,
#  "one can sit quietly on a chair and the perspiration runs quietly down one's cheeks in drops, and i often wonder that i am so warm and feel it so little.": 0,
#  'to be sure, in these log cabins one is in very close contact with the heat of the sun; we have the sun standing almost all day at our front door.': 5,
#  'if one has a little shady spot outside, it is much easier to get along than at times in germany.': 4,
#  'however, this summer is said not to be equal to the ones in former years; the last few weeks we again had cooler nights.': 8,
#  'the change in the weather is so sudden here that it is really amazing.': 0,
#  'now it is again very warm, but last week i wanted to have somebody go and fetch our featherbeds from the new house.': 0,
#  'a few weeks ago kolk showed us a little nest of hummingbirds; it sat there attached to the extreme end of an oak branch and was as big as a walnut half.': 1,
#  'the pretty little bird buzzed around his little building.': 5,
#  'we regretted very much that the slender tree with its far-reaching branch prevented closer observation.': 3,
#  'twice already indians have been nearby.': 1,
#  'at first there was a group in lisletown, where a mr williams speaks their language.': 7,
#  'they drank mightily until someone finally thought it wise to show them the door.': 5,
#  "a little while ago again forty indians with wives and children appeared in the swedes' store on the osage; they love whiskey very, very much.": 4,
#  'the women simply are told to go into the woods, where they make a fire and prepare their food until the men feel like eating or lying down.': 5,
#  'the men swam through the osage on top of or alongside their horses, shouting wildly; all who saw it were amazed at their skill in guiding their canoes very quickly.': 3,
#  'there is no thought of danger or attack.': 7,
#  'they obey as soon as they are told.': 0,
#  'unfortunately i heard of their stay at the osage too late; otherwise i would have ridden over there because i have not seen any yet.': 0,
#  'we have a few hundred plants of tobacco; it grew very well even though we did not have much time to care for it, nor did we plant it early enough.': 1,
#  'the big, heavy leaves hang down and can be taken off.': 1,
#  'the tobacco resembles the plant that we used to have in the little yard.': 5,
#  "25 september '37 fortune is smiling at me; two sundays in succession now we have received letters.": 2,
#  '(it has now been four weeks that i have wanted to send this letter to you, and it is still not finished.)': 2,
#  'you have written something about bonn and your stay there.': 2,
#  'since your first letter was lost i only knew you were studying there.': 2,
#  'do write frequently; your sister is not a stranger to the rhine.': 0,
#  'have you visited stolzenfels yet?': 4,
#  'when you walk up the small, narrow, winding path you can think of me.': 0,
#  'i spryly followed our stout uncle, who finally arrived with me at the top completely exhausted.': 0,
#  'i was dizzy and i did not dare approach the edge of the precipice; but how beautiful was the friendly valley in front of us, how gently did the lahn wind its way into the mighty stream.': 1,
#  'i still remember this scene vividly.': 2,
#  'will you stay in bonn in the future?': 0,
#  'do repeat a few of the things from the lost letter.': 6,
#  'what will mr hesse be doing in germany?': 0,
#  'uncle caspar announced his arrival.': 2,
#  'we would be interested in hearing from him has fritz schwarze arrived?': 6,
#  'will he return?': 0,
#  'the immigrants here still have to suffer a great deal from the missouri rash.': 3,
#  'the main cause is that they eat too much meat,report: and then also they live on land that has not been cleared.': 8,
#  'many of them do not know about this.': 0,
#  'max and hermann have little blisters on their hands and feet and are amazingly annoyed at this, which mother has to bear with patience.': 5,
#  'the fever, which was quite tolerable during the summer, now appears more frequently.': 0,
#  'in our house bruns, franz, david, jenne, and little max were spared.': 6,
#  'we others did have a taste of it.': 5,
#  'but i feel quite well again.': 4,
#  'it was bad in the other house, where the wife of the carpenter had three or four attacks.': 7,
#  'and then jenne had to cook there, or the carpenters had to do it themselves.': 8,
#  'it is the usual cold fever.': 0,
#  'now farewell and remain well, write diligently; you see how quickly letters can fly across the ocean.': 4,
#  'i will soon be happy that we can converse with each other in this manner.': 4,
#  'only too often, however, i lack the time to be able to write calmly.': 2,
#  'in the new house, where i can sit down by myself, it will be better, but when there is so much restlessness around me, i lack the peace.': 4,
#  'i often fear that i communicate to you the least interesting things; you will have to pass over this.': 2,
#  'bruns, who rode twenty-six miles today, sends his greetings from his bed.': 0,
#  'franz is active and sends sincere greetings even though he is not at home right now.': 4,
#  'he went to get apples from the other side of the missouri.': 8,
#  'he went by boat with the others.': 0,
#  'the fruit is cheap there and very nice.': 8,
#  'there are also a lot of peaches.': 8,
#  'hold dear, as always, your sister jette.': 4,
#  'on 13 october 1837 heinrich wrote jette, describing the dismantling of the family business in münster.': 4,
#  'he reported rumors that "bruns is said to have moved away because of an investigation concerning the burschenschaft" {the student fraternity} and further that "bruns is supposed to have remarked that if things do not turn out better he will return.': 6,
#  'it is not as good over there as he had imagined."': 4,
#  'heinrich was frustrated that he could neither confirm nor deny the rumors.': 2,
#  'on christmas day 1837, jette wrote to uncle caspar, reporting that the family had moved into the new house six weeks before.': 0,
#  'they had the use of three rooms and cooked in a building next door.': 0,
#  'she had a second maid "to share the burden of the household."': 4,
#  'franz was doing well as a farmer, but she was worried about bernhard, who had been ill and was acting strangely.': 3,
#  ' westphalia settlement 1 march 1838 dear heinrich: mr lamken was kind enough to bring a letter for us to lisletown from jefferson.': 2,
#  'mr niedieck brought it along here.': 5,
#  'i happened by chance to be unwell and had a severe headache, but i wanted to see it, and i read and i read, and i skimmed over many things, and i thought that i would have to read it again and then i went to bed.': 2,
#  'until niedieck said, "so this was already written in 1836?"': 2,
#  'and then i was very happy that this first letter had finally reached its destination.': 2,
#  'and brother heinrich was still in very good spirits and probably while writing looked happier than his older sister when she saw brother bernhard read the letter and make a strange face, almost tearful, then terribly serious, then stop at some spot for a long time, and finally look at me frequently without expression and without saying a word.': 2,
#  'bernhard has gained a lot of strength in the last few days; he has become almost as strong as he was before, and it seems he is physically completely healed.': 6,
#  'however, he has lost all his former urge to be active, he is distracted, and can sit all day long full of thoughts.': 0,
#  'the shyness is almost the same; only now and then a smile comes over his expressionless face, and he merely answers with a short yes or no to any question that is directed to him.': 2,
#  "i don't know what will become of him!": 0,
#  'often i think when he sits there so quietly without taking part in what is going on that he is still very low; later when he speaks with me very reasonably and as usual, when i select this or that text that is appealing to him, then i think that everything will soon be fine again.': 0,
#  'bruns shrugs his shoulders and is hoping for the best!': 5,
#  "14 march i've been waiting for a long time for a letter from you.": 2,
#  'in august we received your last letter.': 2,
#  'now in the middle of march it has been six and one-half months.': 8,
#  'heaven knows, if it does not get better soon, then it will make me nervous.': 3,
#  'and it is strange how every more cheerful turn of the mind is immediately depressed.': 7,
#  'for some time now i have written so many things in my thoughts and described to you the situations and the people of the settlement here, and it only required a few calm hours in order to find these thoughts again.': 3,
#  'today young mrs huber was buried.': 4,
#  'it has been almost two weeks since she rushed into the arms of her husband already dying and completely enveloped in flames.': 4,
#  'she suffered tremendously.': 3,
#  'her face, arms, and shoulders had been burned.': 5,
#  'still affected by giving birth and by the death of her second son, she must have been overcome by dizziness, for she could give no other reason for the outbreak of the fire.': 2,
#  'often i have admired her heavenly patience when she was suffering those severe pains.': 3,
#  'the wounds began to heal, she could see with both eyes, but the fever became stronger, the fire went inside, and she died last monday.': 3,
#  "how easily man's life is wiped out!": 7,
#  'she was not yet twenty years old.': 8,
#  'not much of my work got done in those days.': 0,
#  'i can see in my notes the name of blumenthal; so for my and your diversion let me tell you a little bit more.': 5,
#  'blumenthal and pitterson were educated swedes who spoke pretty good german (also english and french).': 4,
#  'the former was very musical.': 0,
#  "they established a store on the osage above vennewald's farm.": 1,
#  'they were well liked by the germans and visited hubers, us, and others at times.': 2,
#  'pitterson traveled with his goods up the osage for about a hundred miles, but his business went poorly.': 1,
#  'he had come back in the morning, and blumenthal came to get medicine for him in the evening.': 0,
#  'he was monosyllabic and immediately left again.': 0,
#  'bruns was not here.': 0,
#  'the next morning mr shipley asked bruns to come over because the store was closed.': 0,
#  'when they opened the door they found everything in good order; all the goods were there, only a few pieces of their clothing were missing, and their canoe on the osage was not there.': 5,
#  'soon thereafter mr menges read in the paper in st louis a report from st charles that a body had been found in the missouri.': 2,
#  'the description fit pitterson, but another body had been taken away by the missouri.': 5,
#  'this event has occupied us very much.': 0,
#  'but now something else!': 0,
#  'now and then, when it occurs to us, we partake of the bag of nuts.': 5,
#  'they grow here in tremendous amounts.': 1,
#  'in an hour, in a space as big as our living room, i picked a whole big bag.': 1,
#  "then one throws it on one's horse and trots casually home.": 5,
#  'while picking them i thought, if i could only bring them back to your study!': 4,
#  'the walnuts are not as good here the shells are so tough and thick that it is not worth the trouble to crack them.': 5,
#  '21 april for two weeks now i have been in possession of a letter from you dated 6 november that was dispatched one month later.': 2,
#  'i was going to say that we had expected it earlier and then i found a little note to bernhard: "münster, september."': 6,
#  "it came from niedieck's letter.": 2,
#  'so this is "the last letter" of which you wrote.': 2,
#  'hmmm!!!': 0,
#  'well, in compensation this one is also (three hours later) curse the eternal distractions on sunday, always visitors!': 6,
#  'your letter is quite long and pleasant.': 2,
#  'but you have to write more frequently; seven months is really too long.': 2,
#  "everything that you write is good and nice, but do say at random whatever occurs to you; the more joy, the more good spirits, the more your sister's eye will laugh, and the more happy we will be, all of us.": 6,
#  "don't let the pen be drawn so rarely for us; how could you leave it unused many a day from six to eight in the evening!": 0,
#  '"i imagine your life is certainly idyllic."': 4,
#  'certainly, certainly, dear heinrich, but let me sketch a little.': 4,
#  'spring is as beautiful, i almost believe, as it is with you; i welcome it much more than i did last year; it is much prettier.': 8,
#  'our farm is getting more friendly every day.': 0,
#  'from the bedroom where i am writing the yard forms the foreground, the red blossoms of the judas tree and the white of dogwoods, the sprouting green between the rocks then straight in front of me, approximately fifty paces gently down hill, is the little gate to the bottom field.': 1,
#  'here is the garden where mrs bruns has been busily occupied during the past two weeks and enjoys the sprouting peas, beans, and other plants by the hour.': 0,
#  'the garden forms the center of the field.': 1,
#  'to the right is a stretch of plowed field with oats, to the left there are some trees that have been killed, some bushes and low-lying land that i hope will be replaced by a few fields of corn this summer.': 1,
# ...
#  'jenne has gone to a rhinelander about three miles from here where she works, and she also has a love affair.': 4,
#  'there is no one who can be more foolish than she!': 3,
#  'now heaven sends us more and more rain; presently the bottom land, which has been flooded, is one big lake.': 1,
#  'the water flows through the meadows, the split rails are lifted up and float away, the water is still rising another three or four feet and the entire bottom will be under water, and then everything will be gone and all the toil and work of last spring will have been in vain.': 1,
#  'as god wishes!': 0,
#  'but it would be too hard on us and on most of the settlers on the maries.': 7,
#  'the 10th it went well after all.': 0,
#  'the water is gone.': 1,
#  'we do have to go and get some of the split rails back, and then everything will be in its old condition.': 3,
#  'the pasture will have a strong fence.': 8,
#  'bruns is urging, and i have to come to a close.': 3,
#  'so long, and write soon to your sincerely loving sister, jette.': 4,
#  ' august 1839 dear heinrich: now it is the middle of august, and still i have only your letter of 16 march as the last to arrive here.': 2,
#  'i am patient enough, but my mood is getting a little strange, and many a day passes without joy when my little ones chase away equanimity.': 0,
#  'brother heinrich studies, dreams, etc, etc, but the leisure hours for us are very rare!': 0,
#  'so, from the very beginning i shall write my complaints, and then to something else.': 2,
#  'h niedieck causes us a great deal of concern and unrest as never before.': 6,
#  'about twelve days ago bruns and mr meyer prevailed upon him to leave the business.': 0,
#  'obligingly he wrote and agreed that it would be better this way.': 0,
#  'his drinking took preference over everything else.': 5,
#  'last sunday, suddenly bruns and the pastor were called for again.': 7,
#  'niedieck was dangerously ill, the consequence of drinking; morbid convulsions, apoplexy; to be sure a mild case had affected his arm.': 5,
#  'bruns got him back in shape, and he was brought here, but he is drinking again and carries out stupid pranks.': 5,
#  'bruns took him for further recuperation to a farmer, but he left the house on the second day, rushed to a tavern, and spent all the little pocket money that bruns had felt necessary for him, drinking.': 0,
#  'i have to admit that this bothers me.': 2,
#  'how will it end?': 6,
#  "with his return to germany, if god's patience spares his life.": 6,
#  'i hope it will come to this soon!': 6,
#  'bruns has done everything for him that he could.': 0,
#  'the establishment of the store here in the house was the last and most decisive.': 1,
#  'now he has ingratitude, slander, etc only when niedieck believed himself close to death did he act fairly toward bruns.': 4,
#  'in the presence of linnemann, where he was cared for, he made all kinds of confessions without reservation!!!': 6,
#  "i don't want to write any more of this, but my head is so full that i'm not capable of writing a decent letter to aunt boner.": 2,
#  'for quite some time i have started to write but i cannot finish.': 2,
#  'the construction of the storeroom has taken much time.': 8,
#  'there is no end to the hammering and banging around in the house, the kitchen next, and perhaps the living room, and that will be all.': 0,
#  "so next year we'll continue!": 8,
#  'how sick i am of all this!': 0,
#  'every day i think how i would have been satisfied to live with my husband and the children and franz in a little log cabin and be able to do everything myself.': 4,
#  'i would like to move again, far out into the world!': 3,
#  'while reading this you will make a very serious face, brother heinrich.': 4,
#  'well, now i shall see whether i can write a little better.': 2,
#  'generalities sound good.': 6,
#  'westphalia is coming up in the world, it is a town.': 1,
#  'now all who live here seem to get ahead; and there are a carpenter, a cabinetmaker, a blacksmith, a gunsmith, a butcher, a shoemaker, and next week there will be a tailor.': 5,
#  'two more houses are being built.': 1,
#  'and then a family from hesse, old menke, otto, eck.': 4,
#  'it may appear somewhat unseemly if i let the gentlemen priests with their church and school come last.': 4,
#  'presently we still hope to get a college here.': 7,
#  'gramatica is collecting signatures.': 2,
#  'a few weeks ago the superior (verhaegen) was here and stayed with us.': 0,
#  'mrs bruns did her very best.': 0,
#  'i shall try to present to you the right reverend gentleman.': 3,
#  'his figure: middle-sized, rather stout, but agile at the same time, his complexion red, brown plain hair, lively blue eyes, a full voice, sometimes somewhat shrill.': 5,
#  "his character, as i know him, quick, at times too rash, mocking, spouting severe principles, and then, when he wants to be, tolerant and friendly, above all eloquent, with a great dexterity in his speech; he knows how to make himself pleasing to everybody and to put himself into everybody's situation, indeed a fine man of the world!": 7,
#  'if one would see him without knowing him, see how he attracts everybody in the community with his lively, merry, always kidding and arguing manner, one would think him to be god knows who.': 4,
#  'and yet one never feels that he lacks for a moment anything that is fitting a catholic priest.': 4,
#  'in normal life he has very little dignity.': 3,
#  "he chats around, he expresses his wonderment at fr bischots's healthy appearance, he corrects fr helias's bad pronunciation, he takes care of the sick, he cooks with the housewife, he works in the field with the farmer, but the proper moderation is never exceeded, there is never a glass of wine too many drunk, never anything too delicate eaten, and never an argument that is too lively.": 6,
#  '(perhaps his joking around with his colleagues could be a little less.)': 3,
#  'if one now looks at him as an orator, i would maintain i have never heard a better one, and yet i do not understand more than half of what he says because he speaks only english.': 2,
#  'kellermann did not have half the skill in language, in position, in gestures.': 3,
#  'too bad that the voice of the superior is somewhat harsh.': 3,
#  'the only thing that occasionally attracts attention is his attitude, which is too serious, the delivery fitting the occasion.': 6,
#  'in a short time it will be decided whether the potosi road will come here; it would do a great deal for the progress of the town.': 7,
#  'so often in my thoughts i work out scenes from the settlement.': 1,
#  'so many interesting things happen here, and some people are quite amusing.': 3,
#  'but my pen lacks the power and the confidence to deliver anything tolerable.': 3,
#  'perhaps i shall try it after all.': 0,
#  '13 october in vain i have been waiting week after week for news from you.': 0,
#  'the letter to aunt boner has been lying here for a long time, but i had a feeling that i could not let it go on its way, as if i would have to add something to it.': 2,
#  'often the suspicion overcomes me, bad suspicion, that something bad has happened to you or to your letters.': 3,
#  'stupid stuff!': 4,
#  'well, soon we shall see.': 0,
#  "but it's incredible that johanna does not write at all!": 0,
#  "i really don't know what you are thinking!": 0,
#  'it is getting worse and worse from year to year, and in the end a single letter will come once a year, and the letters will then no longer bear the fresh, plucky style, the sympathetic style that is so characteristic of youth, but will gradually change into the serious, calculating tone of a philistine.': 3,
#  'yet what am i saying; may it never come to this with you, and may the same not be the case with us.': 7,
#  'you will easily believe that in spite of many things that are not very pleasant we can still be quite happy.': 6,
#  'when father bruns tells a joke, the housewife laughs with the others, and then the boys and the girl laugh.': 2,
#  'my johanna is really a darling child, always friendly, and now she is getting so lively she scratches and squeaks and plays with her brothers.': 4,
#  'she still does not have teeth.': 6,
#  'but her mother will soon be toothless.': 4,
#  'at the present time she has a swollen cheek again after the disturber of the peace was yanked out.': 3,
#  'now i shall close.': 5,
#  'perhaps i shall begin a new method to extort an answer from you, and i will write every four weeks.': 2,
#  'farewell!': 0,
#  'write soon where you are, what you are doing, what you will do, and do not forget that your sister in america is thinking of her brothers and sisters every day in painful uncertainty.': 4,
#  'many greetings from bruns and the brothers and your loving sister jette.': 4,
#  'in late 1839 jette received a letter from her cousin marie with news of friends and family members in münster.': 2,
#  'marie writes that it is sometimes reported that jette and her family will soon return to germany.': 0,
#  ' sunday, 17 january 1840 dear heinrich: yesterday letters arrived from f niedieck that had crossed the ocean in twenty days.': 0,
#  'quickly, very quickly, good fortune can bring news, but it does not smile on me.': 5,
#  "there was a note in the margin of niedieck's letter saying that sister johanna was in münster.": 2,
#  '"yesterday i found her and her brother heinrich in a gay circle, a few days earlier at the cecilia ball."': 0,
#  'this sounded very nice.': 6,
#  'so you are well, you love gay company; that is nice, i do not begrudge it to you, and yet i feel a pang in my heart.': 4,
#  'you cannot set aside a little time from your leisure at very definite times twice a year to send a letter to us, to me.': 2,
#  'have you lost all sympathy for me?': 4,
#  'why were you able to write before such loving, open, friendly letters?': 4,
#  'certainly it is extremely irritating to me that you do not let us hear from you; not a thing since the third of june.': 2,
#  'you do know how much warm affection i have for you.': 4,
#  'should the bond of sisterly love be dissolved because the ocean separates us?': 3,
#  'or is it perhaps that a letter was lost?': 2,
#  'but the letters from niedieck and uncle caspar arrived regularly.': 2,
#  "you have so much to tell us: your leave from berlin, your trip via dresden to münster, and the change that you saw there because of uncle adolf's death, concerning which i would have liked so much to hear something more.": 2,
#  'did he also speak of us during his illness, was he annoyed or indifferent?': 7,
#  'the first news of his passing touched me very much.': 5,
#  'now, however, i am calm again because i do not feel any guilt toward him, and if he should have misjudged me then, now he will think well of me again.': 3,
#  'to be sure how i would have loved to have seen a few lines from him.': 4,
#  'write me a lot about him from the time of his illness and more.': 2,
#  'what will happen to our uncles when the house is sold?': 8,
#  "it's a shame about the beautiful garden.": 1,
#  'thereschen and wilhelm, where will they stay?': 0,
#  'how are they?': 0,
#  'uncle caspar thought that thereschen should go to the country because she is so frail.': 8,
#  'i still do not know anything definite about johanna.': 1,
#  'uncle caspar writes of permanent fetters; marie thought that they were talking of an engagement.': 2,
#  'now i would be very much inclined to interfere and make myself important.': 7,
#  'i have already written to uncle caspar, as he has probably told you.': 2,
#  'i have told him of what i could properly remind him, and perhaps also more.': 3,
#  'but how could i do it differently, to whom should i turn?': 6,
#  'brother heinrich does not consider it worth the trouble to answer me.': 2,
#  'i doubt that you will take up my cause in this.': 6,
#  'i am interested in having johanna here, but you are probably not.': 6,
#  'she has written to me and to bernhard that she would not desire anything more than to be with us, she would consider this her greatest happiness, etc, etc six weeks later she is supposed to have found an entirely different bliss, and at this time uncle caspar knows it already!': 6,
#  'incredible!': 5,
#  'outrageous!': 8,
#  'heinrich, you must write me, you must not delay any more.': 2,
#  'to be sure my hope is almost gone, but do let me know for sure.': 6,
#  'johanna must write to me herself.': 2,
#  'i am thinking of this day and night.': 0,
#  'we are now in the process of building a mill and have many workmen here every day.': 7,
#  "but i am sick of all this unrest, and i've told franz that he should take a wife so that i could be relieved.": 4,
#  'the mill business concerns him and bernhard too.': 2,
#  "but he is much too dry and stiff and doesn't want to hear of this.": 5,
#  'if i want to turn to bernhard, he would more likely follow suggestions.': 7,
#  'i am so happy that bernhard is now with robinson.': 0,
#  'this place seems just the right one for him.': 1,
#  'he wants to stay there all summer if the good lord keeps him healthy.': 6,
#  'zumnorde is nearby, staying with a loughlin in order to work and to learn english.': 7,
#  'zumnorde has purchased land on the little maries, approximately four miles from here.': 8,
#  'he still likes the life of a farmer quite well.': 8,
#  "3 february finally your and johanna's letter arrived, dated november 27th, '39.": 2,
#  'i am almost glad that an earlier one got lost, but no, i still expect it.': 3,
#  "well, so it isn't quite as bad as i thought.": 4,
#  'the letter which just arrived, however, is tremendously diffused, so i have trouble in understanding its meaning.': 2,
#  'as to johanna, i am happy that her confidence is still given me, but at the same time i am vexed that i have spoken of this matter to uncle caspar, insofar as it has annoyed him.': 3,
#  'should he tell you about this, then tell him that i am sorry and i ask his forgiveness.': 6,
#  'i was deeply hurt, and since johanna herself wrote, even more so.': 4,
#  'why should i hide it from you?': 5,
#  'now, however, i am again devoted to my duties.': 7,
#  'how little i was prepared to suffer with patience the consequence of our estrangement, which happened so late.': 6,
#  'i shall never, never again see her!': 0,
#  'the good lord has given me a good, a very good husband.': 6,
#  'that i realize more and more.': 4,
#  'i also have to agree again and again that it was to my credit that i yielded to his wish to move here.': 8,
#  'our marriage is blessed, and i have to find my peace in the domestic circle.': 3,
#  'but two of my brothers followed us.': 4,
#  'they both are to replace the ones who were left behind, to be everything to me!': 5,
#  'i wish they were not here!': 0,
#  'but the lord has done well with everything!': 0,
#  'our situation here is pretty good.': 3,
#  'as you know, we have made a tremendous mistake by building.': 6,
#  'to be sure, the medical practice and our farm will gradually remedy the situation again.': 3,
#  'bruns and niedieck wrote of speculations, etc our brother is trying to help h niedieck again, but this would not work without bruns.': 2,
#  'so money arrived, carrying high interest; the money has to earn something, and so a few pieces of property were bought.': 8,
#  'h niedieck did not want to, but bruns had vouched for it, and o sends, uncle caspar writes, he takes over a lot, and my brothers are partners.': 2,
#  'already one good farm has been sold at a good price.': 8,
#  'what should be done with the other money?': 8,
#  'franz and bernhard do not like to speculate, mrs bruns shakes her head if she hears of this, and bruns cogitates and thinks about it.': 5,
#  'in the end they consult each other and decide to leave it with the mill and later start a distillery.': 0,
#  'i should remind you that if franz would have a household and a wife it would be better to have the mill and what follows put on his farm.': 8,
#  'niedieck tried to persuade bruns to begin a store with him.': 4,
#  'it was the last and only opportunity to be of use to niedieck, and so bruns consented.': 3,
#  'when niedieck returned from st louis with ferdinand meyer, he was already drunk every day.': 0,
#  ...}

# %%
df['topicNumber'] = df['Sentence'].map(map_sentenceText_topicNumber)
df
# Out:
#        Unnamed: 0                                           Sentence  \
# 0               0   baltimore 20 september 1836 dear heinrich: fr...
# 1               1                  it was a long and arduous voyage!
# 2               2  however we were and are all well and thank the...
# 3               3  i had written down the events of the voyage fo...
# 4               4               as you know, we set sail on 12 july.
# 5               5  by the afternoon, when the pilot left us, one ...
# 6               6  the next morning i felt ill and remained in be...
# 7               7                         later i was always spared.
# 8               8  the wind was adverse from the very first eveni...
# 9               9  on the open sea things went fine in the beginn...
# 10             10  the longing to reach land as soon as possible ...
# 11             11  the water was very bad, and the food was not v...
# 12             12       but there were lots of other things lacking.
# 13             13  how i pitied others when i dined with hermann ...
# 14             14        there was scarcely any other shade on deck.
# 15             15  mrs ossenbeck from everswinkel was happily del...
# 16             16  he was baptized by the chaplain and received t...
# 17             17                                    the godparents?
# 18             18                 captain j h spilker and mrs bruns.
# 19             19  a festive noon meal followed, in which schnied...
# 20             20                            we saw only a few fish.
# 21             21  once a dolphin was caught and provided us with...
# 22             22            otherwise the trip was very monotonous.
# 23             23  great was everybody's joy when the pilot ship ...
# 24             24  it was late the evening of the 12th when we en...
# 25             25  and then there was another calm and we often h...
# 26             26  saturday, the 17th, after the doctor had left ...
# 27             27  we were very sincerely happy to have firm soil...
# 28             28                           we spent the night here.
# 29             29  on sunday morning we went with hermann to the ...
# ...           ...                                                ...
# 43995       43995  such articles are intended only to deceive ign...
# 43996       43996  there are those who would benefit from its abr...
# 43997       43997  it has happened that norwegian families who ha...
# 43998       43998  they have not been able to find adequate work ...
# 43999       43999  some, however, have been rather lucky in calif...
# 44000       44000   a generation after the organized emigration o...
# 44001       44001  (source: nordmands-forbundet, iii [1910], 282-...
# 44002       44002  perhaps that would encourage our feeling of na...
# 44003       44003  deep at heart we are all norwegians and proud ...
# 44004       44004  on the other hand, we are so cosmopolitan that...
# 44005       44005  here on maui there are fifteen or twenty norwe...
# 44006       44006  we hardly ever can all get together because th...
# 44007       44007  even though our conversations then alternate b...
# 44008       44008   few norwegians settled in mexico, but carl v ...
# 44009       44009  (source: nordmands-forbundet, iii [1909-1910],...
# 44010       44010  in recent years some young people have come to...
# 44011       44011  tres faciunt coelegium, they say, so one could...
# 44012       44012     we have been here together for thirteen years.
# 44013       44013  the foreign groups live independently of each ...
# 44014       44014  the germans, who are the most numerous, have t...
# 44015       44015  others who happen to know the language can bec...
# 44016       44016  the spaniards also have their own casino, whil...
# 44017       44017  we norwegians associate most with the english ...
# 44018       44018  but when we want to have a really good time we...
# 44019       44019  the standing rule is that no foreigners are ad...
# 44020       44020  if there are norwegian ships in port, their ca...
# 44021       44021  one brings some herring, another half a bottle...
# 44022       44022  we have a good time and sing our good old song...
# 44023       44023  small, improvised parties of this kind help to...
# 44024       44024  everyone has something to say, so one makes ne...
#
#                 fileid  Sequence  Sentiment  topicNumber
# 0      S10003-D023.txt         1     0.7263            1
# 1      S10003-D023.txt         2     0.0000            6
# 2      S10003-D023.txt         3     0.8777            7
# 3      S10003-D023.txt         4     0.2263            6
# 4      S10003-D023.txt         5     0.0000            0
# 5      S10003-D023.txt         6     0.0000            7
# 6      S10003-D023.txt         7     0.5267            0
# 7      S10003-D023.txt         8     0.0000            6
# 8      S10003-D023.txt         9    -0.3612            0
# 9      S10003-D023.txt        10     0.8020            6
# 10     S10003-D023.txt        11     0.6124            7
# 11     S10003-D023.txt        12    -0.1604            5
# 12     S10003-D023.txt        13     0.0000            6
# 13     S10003-D023.txt        14     0.4215            0
# 14     S10003-D023.txt        15     0.0000            0
# 15     S10003-D023.txt        16     0.5574            7
# 16     S10003-D023.txt        17     0.0000            2
# 17     S10003-D023.txt        18     0.0000            1
# 18     S10003-D023.txt        19     0.0000            0
# 19     S10003-D023.txt        20     0.4588            0
# 20     S10003-D023.txt        21     0.0000            5
# 21     S10003-D023.txt        22     0.0000            5
# 22     S10003-D023.txt        23     0.0000            6
# 23     S10003-D023.txt        24     0.8360            3
# 24     S10003-D023.txt        25     0.0000            7
# 25     S10003-D023.txt        26     0.3182            1
# 26     S10003-D023.txt        27     0.0000            0
# 27     S10003-D023.txt        28     0.9056            8
# 28     S10003-D023.txt        29     0.0000            0
# 29     S10003-D023.txt        30     0.0000            0
# ...                ...       ...        ...          ...
# 43995   S9983-D110.txt        15    -0.5719            7
# 43996   S9983-D110.txt        16    -0.5267            2
# 43997   S9983-D110.txt        17     0.4767            4
# 43998   S9983-D110.txt        18     0.7717            6
# 43999   S9983-D110.txt        19     0.4215            8
# 44000   S9983-D111.txt         1     0.0000            1
# 44001   S9983-D111.txt         2     0.8960            3
# 44002   S9983-D111.txt         3    -0.0258            4
# 44003   S9983-D111.txt         4     0.4767            4
# 44004   S9983-D111.txt         5     0.4939            6
# 44005   S9983-D111.txt         6     0.0000            0
# 44006   S9983-D111.txt         7     0.0602            7
# 44007   S9983-D111.txt         8     0.0258            3
# 44008   S9983-D128.txt         1     0.0000            5
# 44009   S9983-D128.txt         2     0.1440            2
# 44010   S9983-D128.txt         3     0.0000            8
# 44011   S9983-D128.txt         4     0.0000            4
# 44012   S9983-D128.txt         5     0.0000            8
# 44013   S9983-D128.txt         6     0.0000            1
# 44014   S9983-D128.txt         7     0.0000            1
# 44015   S9983-D128.txt         8     0.0000            7
# 44016   S9983-D128.txt         9     0.6369            1
# 44017   S9983-D128.txt        10     0.2732            0
# 44018   S9983-D128.txt        11     0.6946            6
# 44019   S9983-D128.txt        12    -0.2023            3
# 44020   S9983-D128.txt        13     0.4588            0
# 44021   S9983-D128.txt        14     0.2732            5
# 44022   S9983-D128.txt        15     0.8519            3
# 44023   S9983-D128.txt        16     0.8316            5
# 44024   S9983-D128.txt        17     0.0000            2
#
# [44025 rows x 6 columns]

# %%
df.to_csv('20201119_AM_Latent2Merge.csv', index=None)
